# %%
import xarray
import pygmt
import pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
ds = xarray.open_dataset("../data/MIROC_outputs/ctrl_MIROC-COSP2.nc")

# %% [raw]
# print(ds.info())

# %%
# %%capture

vname='vfall_T'
var=ds[vname]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/myenvs/py-yuhi_n/lib/python3.13/site-packages/xarray/core/dataset.py in ?(self, name)
#    1230             variable = self._variables[name]
#    1231         except KeyError:
# -> 1232             _, name, variable = _get_virtual_variable(self._variables, name, self.sizes)
#    1233
#
# KeyError: 'vfall_T'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/myenvs/py-yuhi_n/lib/python3.13/site-packages/xarray/core/dataset.py:1337, in Dataset.__getitem__(self, key)
#    1336 try:
# -> 1337     return self._construct_dataarray(key)
#    1338 except KeyError as e:
#
# File ~/.pyenv/myenvs/py-yuhi_n/lib/python3.13/site-packages/xarray/core/dataset.py:1232, in Dataset._construct_dataarray(self, name)
#    1231 except KeyError:
# -> 1232     _, name, variable = _get_virtual_variable(self._variables, name, self.sizes)
#    1234 needed_dims = set(variable.dims)
#
# File ~/.pyenv/myenvs/py-yuhi_n/lib/python3.13/site-packages/xarray/core/dataset_utils.py:79, in _get_virtual_variable(variables, key, dim_sizes)
#      78 if len(split_key) != 2:
# ---> 79     raise KeyError(key)
#      81 ref_name, var_name = split_key
#
# KeyError: 'vfall_T'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/x2/0z810s1x6rv88_mcl1qlvyc00000gn/T/ipykernel_62762/3348821148.py in ?()
#       1 vname='vfall_T'
# ----> 2 var=ds[vname]
#
# ~/.pyenv/myenvs/py-yuhi_n/lib/python3.13/site-packages/xarray/core/dataset.py in ?(self, key)
#    1346
#    1347                 # If someone attempts `ds['foo' , 'bar']` instead of `ds[['foo', 'bar']]`
#    1348                 if isinstance(key, tuple):
#    1349                     message += f"\nHint: use a list to select multiple variables, for example `ds[{list(key)}]`"
# -> 1350                 raise KeyError(message) from e
#    1351
#    1352         if utils.iterable_of_hashable(key):
#    1353             return self._copy_listed(key)
#
# KeyError: "No variable named 'vfall_T'. Variables on the dataset include ['longitude', 'latitude', 'tau7_bnds', 'pres7_bnds', 'hgt16_bnds', ..., 'REICE_MODIS', 'RELIQ_MODIS', 'CFODD_NDBZE', 'CFODD_NICOD', 'regimeID']"

# %%
#grids

lat=ds["latitude"].values
lon=ds["longitude"].values

temp=ds["lvtemp_grid"].values
zgrd=ds["lvdBZe_grid"].values
vgrd=ds["lvdplr_grid"].values

# %%
dx = vgrd[1] - vgrd[0]
x_edge = np.concatenate([
        [vgrd[0] - dx/2],
        vgrd + dx/2
        ])

dy = temp[1] - temp[0]
y_edge = np.concatenate([
         [temp[0] - dy/2],
         temp + dy/2
         ])

# %%
south=-20.
north=20.
east=360.
west=0.

# 0:ALL, 1:LSC, 2:CVC
regime=0

# n-th moment: 6(Ze), 3(mass), 0(number)
moment=3

# %%
vmin = 0.
vmax = 2.0
tick = 0.2

if moment==6:
    nmlz = 1
elif moment==3:
    nmlz = 2
elif moment==0:
    nmlz = 3

# %%
# location mask
lon_mask = (lon >= west) & (lon <= east)
lat_mask = (lat >= south)&(lat <= north)

mask = lon_mask & lat_mask

index = np.where(mask)[0]

# %%
sel = var.isel(loc=index).isel(regimeID=regime).isel(nrmlzdID=nmlz)
smpl = sel.sum(dim='loc', skipna=True).values
window = 0.2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sel = var.isel(loc=index).isel(regimeID=regime).isel(nrmlzdID=nmlz)
#       2 smpl = sel.sum(dim='loc', skipna=True).values
#       3 window = 0.2
#
# NameError: name 'var' is not defined

# %%
nrm = window * smpl.sum(axis=1, keepdims=True)
nrm = np.broadcast_to(nrm,smpl.shape)

zero_check = (nrm < window)
cfed = np.zeros_like(smpl)

cfed[~zero_check] = smpl[~zero_check]/nrm[~zero_check]
cfed[zero_check] = np.nan

# %%
# %%capture
plt.figure(figsize=(8, 6))

# %%
extent = [x_edge[0], x_edge[-1], y_edge[-1], y_edge[0]]

im = plt.imshow(cfed,
                extent=extent,
                interpolation='nearest',
                origin='upper',
                vmin=vmin, vmax=vmax,
                cmap='plasma',
                aspect='auto')

plt.xlabel("Doppler velocity axis (index or m/s)")
plt.ylabel("Temperature axis (index or degC)")

plt.tight_layout()
plt.show()

# %%
jmacolors=np.array(
   [
    [242,242,242,1],#white
    [160,210,255,1],
    [33 ,140,255,1],
    [0  ,65 ,255,1],
    [250,245,0,1],
    [255,153,0,1],
    [255,40,0,1],
    [180,0,104,1]],dtype=np.float
)
jmacolors[:,:3] /=256
jmacmap=ListedColormap(jmacolors)
jmacmap2=LinearSegmentedColormap.from_list("jmacmap2",colors=jmacolors)
