# %%
import xarray
import pygmt
import pandas
import numpy as np

# %%
ds = xarray.open_dataset("../data/MIROC_inputs/ctrl_MIROCinput.nc", decode_timedelta=False)

# %%
ds.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	lat = 128 ;
# 	lon = 256 ;
# 	level = 40 ;
# 	hydro = 9 ;
#
# variables:
# 	float64 landmask(lat, lon) ;
# 	float64 skt(lat, lon) ;
# 	float64 orography(lat, lon) ;
# 	float64 sunlit(lat, lon) ;
# 	float64 pfull(level, lat, lon) ;
# 	float64 height(level, lat, lon) ;
# 	float64 height_half(level, lat, lon) ;
# 	float64 T_abs(level, lat, lon) ;
# 	float64 qv(level, lat, lon) ;
# 	float64 rh(level, lat, lon) ;
# 	float64 tca(level, lat, lon) ;
# 	float64 cca(level, lat, lon) ;
# 	float64 mr_lsliq(level, lat, lon) ;
# 	float64 mr_lsice(level, lat, lon) ;
# 	float64 mr_ccliq(level, lat, lon) ;
# 	float64 mr_ccice(level, lat, lon) ;
# 	float64 fl_lsrain(level, lat, lon) ;
# 	float64 fl_lssnow(level, lat, lon) ;
# 	float64 fl_ccrain(level, lat, lon) ;
# 	float64 fl_ccsnow(level, lat, lon) ;
# 	float64 dtau_s(level, lat, lon) ;
# 	float64 dtau_c(level, lat, lon) ;
# 	float64 dem_s(level, lat, lon) ;
# 	float64 dem_c(level, lat, lon) ;
# 	float64 mr_ozone(level, lat, lon) ;
# 	float64 phalf(level, lat, lon) ;
# 	float64 Reff(hydro, level, lat, lon) ;
# 	float64 lon(lon) ;
# 	float64 lat(lat) ;
#
# // global attributes:
# }

# %% [markdown]
# ---

# %%
# %%capture
data=ds["tca"]
data.load()

zid=10
hid=1

# %%
var = data.isel(level=zid)
#var = data.isel(level=zid,hydro=hid)

#lat = ds["lat"].values
#lon = ds["lon"].values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 #var = data.isel(level=zid)
# ----> 2 var = data.isel(level=zid,hydro=hid)
#       4 #lat = ds["lat"].values
#       5 #lon = ds["lon"].values
#
# File ~/.pyenv/myenvs/py-yuhi_n/lib/python3.13/site-packages/xarray/core/dataarray.py:1581, in DataArray.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1576     return self._from_temp_dataset(ds)
#    1578 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    1579 # lists, or zero or one-dimensional np.ndarray's
# -> 1581 variable = self._variable.isel(indexers, missing_dims=missing_dims)
#    1582 indexes, index_variables = isel_indexes(self.xindexes, indexers)
#    1584 coords = {}
#
# File ~/.pyenv/myenvs/py-yuhi_n/lib/python3.13/site-packages/xarray/core/variable.py:1127, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1103 """Return a new array indexed along the specified dimension(s).
#    1104
#    1105 Parameters
#    (...)   1123     indexer, in which case the data will be a copy.
#    1124 """
#    1125 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "isel")
# -> 1127 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1129 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
#    1130 return self[key]
#
# File ~/.pyenv/myenvs/py-yuhi_n/lib/python3.13/site-packages/xarray/core/utils.py:900, in drop_dims_from_indexers(indexers, dims, missing_dims)
#     898     invalid = indexers.keys() - set(dims)
#     899     if invalid:
# --> 900         raise ValueError(
#     901             f"Dimensions {invalid} do not exist. Expected one or more of {dims}"
#     902         )
#     904     return indexers
#     906 elif missing_dims == "warn":
#     907     # don't modify input
#
# ValueError: Dimensions {'hydro'} do not exist. Expected one or more of ('level', 'lat', 'lon')

# %%
lon, lat = np.meshgrid(var.lon, var.lat)
ll = np.column_stack([lon.ravel(), lat.ravel(), var.values.ravel()])

grid = pygmt.xyz2grd(
    data=ll,
    region=[ -180, 180, -90, 90 ],
    spacing="1.5d",
)

# %%
fig = pygmt.Figure()

# %%
region = [ -180, 180, -90, 90 ]

# %%
fig.coast(
    region="g",
    projection="W15c",   # Robinson 投影（15 cm 幅）
    land="lightgray",
    water="white",
    frame="af"
)

# %% [raw]
# pygmt.makecpt(cmap="turbo", series=[float(var.min()), float(var.max())])

# %%
fig.grdimage(
    grid=grid,
    cmap="turbo",
    shading=True,
)

fig.colorbar(frame="af", position="JBC+w10c/0.5c+h")

# %%
fig.show(width='70%')
