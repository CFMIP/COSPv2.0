# %%
import xarray
import pygmt
import pandas
import numpy as np

# %%
ds = xarray.open_dataset("../data/MIROC_inputs/ctrl_MIROCinput.nc", decode_timedelta=False)

# %%
ds.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	time = 7 ;
# 	lat = 128 ;
# 	lon = 256 ;
#
# variables:
# 	int32 landmask(time, lat, lon) ;
#
# // global attributes:
# }
