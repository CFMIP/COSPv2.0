# %% [markdown]
# ## 最近の作業状況

# %% [markdown]
# ### 1. COSP Doppler simulatorの公開に向けて
#
# #### 1.1. オフライン実行
#
# + コードをfixして、オフライン実行用のデータの整備
# + 結果確認用のスクリプトの整備
# + デモにも利用
#
# #### 1.2. 論文
#
# + NICTデータとの比較論文はほぼ完了
# + EarthCAREデータとの比較論文は準備中
#
# ### 2. ECOMIPへのNICAM-SPRINTARSの参加
#
# #### 2.1. 実験
#
# + 現在gl9でのフリーランのみ
# + エアロゾル初期値をナッジングで整備して、2day実験を予定
# + うまくいくようなら、ダウンスケールしてgl11に
#
# #### 2.2. EarthCAREとの比較
#
# + Morioka mtgで示した結果は、quality flagの取り扱いに問題あり
# + 改めて比較結果を示したい
# + AOT, mass ext. coef., COT, CRE, ...

# %% [markdown]
# + タイトルページ
# + 入力ファイルの詳細
# + シミュレータフローチャート
# +
