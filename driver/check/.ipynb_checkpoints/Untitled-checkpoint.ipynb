# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap,LinearSegmentedColormap
import numpy as np

# %%
# [3]
# 気象庁っぽいカラーマップ
jmacolors=np.array(
   [
    [242,242,242,1],#white
    [160,210,255,1],
    [ 33,140,255,1],
    [  0, 65,255,1],
    [  0,185,  0,1],
    [250,245,  0,1],
    [255,153,  0,1],
    [255, 40,  0,1],
    [180,  0,104,1],
    [ 45, 45, 45,1],
   ],dtype=np.float64
)
jmacolors[:,:3] /=256
jmacmap=ListedColormap(jmacolors)
jmacmap2=LinearSegmentedColormap.from_list("jmacmap2",colors=jmacolors)

# %%
# [4]
mm,tmp=np.meshgrid(np.linspace(0,1,256),np.arange(10))
fig,axes=plt.subplots(figsize=(6,6),facecolor="w",nrows=2)

for ax,cmap,title in zip(axes,[jmacmap,jmacmap2],["Listed","Linear"]):
    ax.imshow(mm,cmap=cmap)
    ax.axis("off")
    ax.set_title(title)
